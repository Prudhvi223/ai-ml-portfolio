# %%
import re
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Prudhvi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Prudhvi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Prudhvi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Prudhvi\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Prudhvi\AppData\Roaming\nltk_data...
# True

# %%
text = """
I am learning Natural Language Processing!
NLP is amazing, and I am learning it for my AI/ML journey.
I was running, studying, and building projects.
"""

# %%
print(text)
# Out:
# I am learning Natural Language Processing!
# NLP is amazing, and I am learning it for my AI/ML journey.
# I was running, studying, and building projects.

# %%
text_lower = text.lower()

print(text_lower)
# Out:
# i am learning natural language processing!
# nlp is amazing, and i am learning it for my ai/ml journey.
# i was running, studying, and building projects.

# %%
clean_text = re.sub(r"[^a-zA-Z\s]", "", text_lower)

print(clean_text)
# Out:
# i am learning natural language processing
# nlp is amazing and i am learning it for my aiml journey
# i was running studying and building projects

# %%
tokens = word_tokenize(clean_text)

print(tokens)
# Out:
# ['i', 'am', 'learning', 'natural', 'language', 'processing', 'nlp', 'is', 'amazing', 'and', 'i', 'am', 'learning', 'it', 'for', 'my', 'aiml', 'journey', 'i', 'was', 'running', 'studying', 'and', 'building', 'projects']

# %%
stop_words = set(stopwords.words("english"))

print(list(stop_words)[:20])
# Out:
# ["needn't", 'shan', "they'd", "we'll", 'i', 'against', "didn't", 'your', 'too', 'll', "you've", 'didn', 'my', 'a', 'did', 'o', "you'd", "she'd", 'ourselves', 'its']

# %%
filtered_tokens = [
    word for word in tokens
    if word not in stop_words
]

print(filtered_tokens)
# Out:
# ['learning', 'natural', 'language', 'processing', 'nlp', 'amazing', 'learning', 'aiml', 'journey', 'running', 'studying', 'building', 'projects']

# %%
stemmer = PorterStemmer()

stemmed_words = [
    stemmer.stem(word)
    for word in filtered_tokens
]

print(stemmed_words)
# Out:
# ['learn', 'natur', 'languag', 'process', 'nlp', 'amaz', 'learn', 'aiml', 'journey', 'run', 'studi', 'build', 'project']

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatized_words = [
    lemmatizer.lemmatize(word)
    for word in filtered_tokens
]

print(lemmatized_words)
# Out:
# ['learning', 'natural', 'language', 'processing', 'nlp', 'amazing', 'learning', 'aiml', 'journey', 'running', 'studying', 'building', 'project']

# %%
lemmatizer.lemmatize("running")
# Out:
# 'running'

# %%
lemmatizer.lemmatize("running", pos="v")
# Out:
# 'run'
